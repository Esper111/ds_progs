# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/datasets/product.csv')
df
# Out:
#        Date  Product  Revenue  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0  10-09-23    chips      200         NaN         NaN         NaN
# 1  10-09-23     cola      300         NaN         NaN         NaN
# 2  10-09-23     rice      200         NaN         NaN         NaN
# 3  13-09-23    onion      100         NaN         NaN         NaN
# 4  14-09-23    chips      500         NaN         NaN         NaN
# 5  14-09-23   grapes       80         NaN         NaN         NaN
# 6  14-09-23  biscuit      123         NaN         NaN         NaN
# 7  15-09-23     cake      150         NaN         NaN         NaN
# 8  15-09-23     milk      245         NaN         NaN         NaN
# 9  15-09-23   cheese      170         NaN         NaN         NaN

# %%
df
# Out:
#        Date  Product  Revenue
# 0  10-09-23    chips      200
# 1  10-09-23     cola      300
# 2  10-09-23     rice      200
# 3  13-09-23    onion      100
# 4  14-09-23    chips      500
# 5  14-09-23   grapes       80
# 6  14-09-23  biscuit      123
# 7  15-09-23     cake      150
# 8  15-09-23     milk      245
# 9  15-09-23   cheese      170

# %%
total_revenue = df['Revenue'].sum()
print("Total revenue generated: ",total_revenue)
# Out:
# Total revenue generated:  2068
