# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd

# %%
a=pd.read_csv('/content/drive/MyDrive/datasets/weather.csv')
a
# Out:
#         day  temp  wind speed  event
# 0  01-07-20    24          21   rain
# 1  02-07-20    20          23   rain
# 2  03-07-20    29          44   rain
# 3  04-07-20    30           5  sunny
# 4  05-07-20    25          21  sunny
# 5  06-07-20   -12          33   snow
# 6  07-07-20    24          44   rain
# 7  08-07-20    23          33  sunny
# 8  09-07-20    22          54  sunny
# 9  10-07-20    23          12   rain

# %%
a.head(1)
# Out:
#         day  temp  wind speed event
# 0  01-07-20    24          21  rain

# %%
a.tail(1)
# Out:
#         day  temp  wind speed event
# 9  10-07-20    23          12  rain

# %%
a.columns
# Out:
# Index(['day', 'temp', 'wind speed', 'event'], dtype='object')

# %%
a.day
# Out:
# 0    01-07-20
# 1    02-07-20
# 2    03-07-20
# 3    04-07-20
# 4    05-07-20
# 5    06-07-20
# 6    07-07-20
# 7    08-07-20
# 8    09-07-20
# 9    10-07-20
# Name: day, dtype: object

# %%
a['event']
# Out:
# 0     rain
# 1     rain
# 2     rain
# 3    sunny
# 4    sunny
# 5     snow
# 6     rain
# 7    sunny
# 8    sunny
# 9     rain
# Name: event, dtype: object

# %%
type(a['event'])
# Out:
# pandas.core.series.Series

# %%
a[['event','day']]
# Out:
#    event       day
# 0   rain  01-07-20
# 1   rain  02-07-20
# 2   rain  03-07-20
# 3  sunny  04-07-20
# 4  sunny  05-07-20
# 5   snow  06-07-20
# 6   rain  07-07-20
# 7  sunny  08-07-20
# 8  sunny  09-07-20
# 9   rain  10-07-20

# %%
a['temp'].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0    24
# 1    20
# 2    29
# 3    30
# 4    25
# 5   -12
# 6    24
# 7    23
# 8    22
# 9    23
# Name: temp, dtype: int64>

# %% [markdown]
# std?

# %%
a['temp'].std()
# Out:
# 11.914510294408057

# %%
a.describe()
# Out:
#            temp  wind speed
# count  10.00000   10.000000
# mean   20.80000   29.000000
# std    11.91451   15.405627
# min   -12.00000    5.000000
# 25%    22.25000   21.000000
# 50%    23.50000   28.000000
# 75%    24.75000   41.250000
# max    30.00000   54.000000

# %%
a[a.temp>=27]
# Out:
#         day  temp  wind speed  event
# 2  03-07-20    29          44   rain
# 3  04-07-20    30           5  sunny

# %%
a[a.temp==a.temp.max()]
# Out:
#         day  temp  wind speed  event
# 3  04-07-20    30           5  sunny

# %%
a[['day','temp']][a.temp==a['temp'].max()]
# Out:
#         day  temp
# 3  04-07-20    30

# %%
a.set_index('day')
# Out:
#           temp  wind speed  event
# day
# 01-07-20    24          21   rain
# 02-07-20    20          23   rain
# 03-07-20    29          44   rain
# 04-07-20    30           5  sunny
# 05-07-20    25          21  sunny
# 06-07-20   -12          33   snow
# 07-07-20    24          44   rain
# 08-07-20    23          33  sunny
# 09-07-20    22          54  sunny
# 10-07-20    23          12   rain

# %%
a.loc[:,['event']]
# Out:
#    event
# 0   rain
# 1   rain
# 2   rain
# 3  sunny
# 4  sunny
# 5   snow
# 6   rain
# 7  sunny
# 8  sunny
# 9   rain

# %%
a.loc[a['event']=='snow']
# Out:
#         day  temp  wind speed event
# 5  06-07-20   -12          33  snow

# %%
a.loc[a['day']=='01-07-20']
# Out:
#         day  temp  wind speed event
# 0  01-07-20    24          21  rain
