# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

# %%
df_stocks=pd.DataFrame({'t':['google','unit','ms'],'p':[23,24,25],'eps':[34,45,35]})
df_stocks
# Out:
#         t   p  eps
# 0  google  23   34
# 1    unit  24   45
# 2      ms  25   35

# %%
df_weather=pd.DataFrame({'d':['1/2/23','2/2/23','3/3/23'],'t':[23,24,25],'e':['snow','34','rain']})
df_weather
# Out:
#         d   t     e
# 0  1/2/23  23  snow
# 1  2/2/23  24    34
# 2  3/3/23  25  rain

# %%
with pd.ExcelWriter("/content/drive/MyDrive/datasets/new_name.xlsx") as writer:
  df_stocks.to_excel(writer,sheet_name="stock")
  df_weather.to_excel(writer,sheet_name="weather")

# %% [markdown]
# prog for grpby

# %%
df=pd.read_csv("/content/drive/MyDrive/datasets/weather2.csv")
df
# Out:
#         day    city  temp  windspeed  event
# 0  1/2/2017     nyc    32          6  sunny
# 1  1/2/2017     nyc    25          7   rain
# 2  1/3/2017     nyc    20          8   snow
# 3  1/4/2017     nyc    30          7  sunny
# 4  1/1/2017  mumbai    32          6    fog
# 5  1/2/2017  mumbai    34          5    fog
# 6  1/3/2017   paris    25          6   rain
# 7  1/4/2017   paris    26          7  sunny

# %%
g=df.groupby('city')

# %%
for city,city_gf in g:
  print(city)
  print(city_gf)
# Out:
# mumbai
#         day    city  temp  windspeed event
# 4  1/1/2017  mumbai    32          6   fog
# 5  1/2/2017  mumbai    34          5   fog
# nyc
#         day city  temp  windspeed  event
# 0  1/2/2017  nyc    32          6  sunny
# 1  1/2/2017  nyc    25          7   rain
# 2  1/3/2017  nyc    20          8   snow
# 3  1/4/2017  nyc    30          7  sunny
# paris
#         day   city  temp  windspeed  event
# 6  1/3/2017  paris    25          6   rain
# 7  1/4/2017  paris    26          7  sunny

# %%
g.get_group('')
g.mean()
g.max()
g.describe()
