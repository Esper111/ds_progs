# %% [markdown]
# Different ways to create dataframe
# using csv
# using excel
# from list of tuple
# from dictionary
# from list of dictionaries

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/datasets/weather.csv')
df
# Out:
#         day  temp  wind speed  event
# 0  01-07-20    24          21   rain
# 1  02-07-20    20          23   rain
# 2  03-07-20    29          44   rain
# 3  04-07-20    30           5  sunny
# 4  05-07-20    25          21  sunny
# 5  06-07-20   -12          33   snow
# 6  07-07-20    24          44   rain
# 7  08-07-20    23          33  sunny
# 8  09-07-20    22          54  sunny
# 9  10-07-20    23          12   rain

# %%
df1=pd.read_excel('/content/drive/MyDrive/datasets/weather.xlsx','sheets')
df1

# %%
weather_data={"day":['02/01/2010','04/01/2010','06/01/2010'],"temp":[[21,43,23],[21,33,26],[31,15,43]]}
df2=pd.DataFrame(weather_data)
df2
# Out:
#           day          temp
# 0  02/01/2010  [21, 43, 23]
# 1  04/01/2010  [21, 33, 26]
# 2  06/01/2010  [31, 15, 43]

# %%
weather_data=[('02/01/2010',37,5,'rain'),('03/01/2010',37,6,'snow')]
df4=pd.DataFrame(weather_data,columns=["day","temp","windsped","event"])
df4
# Out:
#           day  temp  windsped event
# 0  02/01/2010    37         5  rain
# 1  03/01/2010    37         6  snow

# %%
weather_data=[{'day':'1/1/17','temp':32,'windspeed':35,'event':'rain'}]
df5=pd.DataFrame(weather_data)
df5
# Out:
#       day  temp  windspeed event
# 0  1/1/17    32         35  rain
