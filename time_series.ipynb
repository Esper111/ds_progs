# %% [markdown]
# pivot -
# pivot table

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/datasets/AAPL.csv")
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-04-03  164.270004  166.289993  164.220001  166.169998  165.287750
# 1    2023-04-04  166.600006  166.839996  165.110001  165.630005  164.750626
# 2    2023-04-05  164.740005  165.050003  161.800003  163.759995  162.890549
# 3    2023-04-06  162.429993  164.960007  162.000000  164.660004  163.785767
# 4    2023-04-10  161.419998  162.029999  160.080002  162.029999  161.169724
# ..          ...         ...         ...         ...         ...         ...
# 247  2024-03-27  170.410004  173.600006  170.110001  173.309998  173.309998
# 248  2024-03-28  171.750000  172.229996  170.509995  171.479996  171.479996
# 249  2024-04-01  171.190002  171.250000  169.479996  170.029999  170.029999
# 250  2024-04-02  169.080002  169.339996  168.229996  168.839996  168.839996
# 251  2024-04-03  168.789993  170.679993  168.580002  169.649994  169.649994
#
#        Volume
# 0    56976200
# 1    46278300
# ...

# %%
type(df.Date[0])
# Out:
# str

# %%
# df = pd.read_csv("/content/drive/MyDrive/datasets/AAPL.csv", parse_dates["Date"])
df = pd.read_csv("/content/drive/MyDrive/datasets/AAPL.csv", parse_dates=["Date"])

# %% [markdown]
# Change the index to date

# %%
# df=pd.read_csv("/content/drive/MyDrive/datasets/AAPL.csv",parse_dates["Date"],index_col="Date")
df = pd.read_csv("/content/drive/MyDrive/datasets/AAPL.csv", parse_dates=["Date"], index_col="Date")
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-04-03  164.270004  166.289993  164.220001  166.169998  165.287750
# 2023-04-04  166.600006  166.839996  165.110001  165.630005  164.750626
# 2023-04-05  164.740005  165.050003  161.800003  163.759995  162.890549
# 2023-04-06  162.429993  164.960007  162.000000  164.660004  163.785767
# 2023-04-10  161.419998  162.029999  160.080002  162.029999  161.169724
# ...                ...         ...         ...         ...         ...
# 2024-03-27  170.410004  173.600006  170.110001  173.309998  173.309998
# 2024-03-28  171.750000  172.229996  170.509995  171.479996  171.479996
# 2024-04-01  171.190002  171.250000  169.479996  170.029999  170.029999
# 2024-04-02  169.080002  169.339996  168.229996  168.839996  168.839996
# 2024-04-03  168.789993  170.679993  168.580002  169.649994  169.649994
#
#               Volume
# Date
# 2023-04-03  56976200
# 2023-04-04  46278300
# 2023-04-05  51511700
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=252, step=1)

# %%
df.loc["2024-03-28"] #retrieve 2024 jan stock prices
# Out:
# Open         1.717500e+02
# High         1.722300e+02
# Low          1.705100e+02
# Close        1.714800e+02
# Adj Close    1.714800e+02
# Volume       6.567270e+07
# Name: 2024-03-28 00:00:00, dtype: float64

# %%
# df.loc["2023-04-03"].close.mean()
df.loc["2023-04-03", "Close"].mean()
# Out:
# 166.169998

# %%
df.loc["2024-01-03"]
# Out:
# Open         1.842200e+02
# High         1.858800e+02
# Low          1.834300e+02
# Close        1.842500e+02
# Adj Close    1.840152e+02
# Volume       5.841450e+07
# Name: 2024-01-03 00:00:00, dtype: float64

# %%
df.close.resample('M').mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-8b737e567718> in <cell line: 1>()
# ----> 1 df.close.resample('M').mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'close'
