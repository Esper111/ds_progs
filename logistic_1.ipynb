# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import pandas as pd

# %%
df=pd.read_csv("insurance.csv")
df.head()

# %%
# %matplotlib inline
plt.xlabel('area', fontsize=20)
plt.ylabel('price',fontsize=20)
plt.scatter(df.area,df.price,color='red',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %%
x_train, x_test, y_train,y_test=train_test_split(df[['age']],df.insurance,test_size=0.1)

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)#1 way to test is by using the test data
# Out:
# array([0, 0])

# %%
model.score(x_test,y_test)
# Out:
# 0.5

# %%
model.predict_proba(x_test)#probab that age grp 20 is 0.6(1st tuple,1st val) not going to purchase is 0.3
# Out:
# array([[0.57253926, 0.42746074],
#        [0.95481051, 0.04518949]])

# %%
model.predict([[38]])#2 way to test is by using any value
#0 means wont take insurance
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
